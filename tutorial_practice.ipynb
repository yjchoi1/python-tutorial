# %% [markdown]
# # Python

# %% [markdown]
# ### Printing

# %% [markdown]
# ### Math
#
# * A + B adds two numbers together
# * A - B subtracts the value B from A
# * A / B divides A by the value B
# * A * B multiplies A by b
# * A ** B raises A to the Bth power
# * A % B gives the remainder of the operation of dividing A by B

# %% [markdown]
# ### Text

# %%
# Out:
# hello world

# %% [markdown]
# ### Lists

# %% [markdown]
# ### For loops

# %% [markdown]
# ### If statements

# %% [markdown]
# Other tyeps of condition checks:
#
# Comparison Operators
# * ==: Checks if two values are equal.
# * !=: Checks if two values are not equal.
# * <: Checks if the left value is less than the right value.
# * <=: Checks if the left value is less than or equal to the right value.
# * \>: Checks if the left value is greater than the right value.
# * \>=: Checks if the left value is greater than or equal to the right value.
# Logical Operators
# * and: Returns True if both statements are true.
# * or: Returns True if one of the statements is true.
# * not: Reverses the result, returns False if the result is true.
# * Membership Operators
# * in: Returns True if a sequence with the specified value is present in the object.
# * not in: Returns True if a sequence with the specified value is not present in the object.

# %% [markdown]
# ### Functions

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# # Numpy Basics

# %%
import numpy as np

# %% [markdown]
# ### Arrays

# %% [markdown]
# ### Indexing

# %% [markdown]
# ### Array filtering

# %% [markdown]
# ### Arrary operations

# %% [markdown]
# # Pandas Basics

# %% [markdown]
# ### Dataframe

# %% [markdown]
# ### Filtering

# %% [markdown]
# ### Adding columns

# %% [markdown]
# ### Indexing

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ### Basic plotting

# %% [markdown]
# ### Subplots

# %%
# Out:
# Text(0, 0.5, 'y axis label')

# %% [markdown]
# # Example: Linear regression

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# If you don't have the data, you can download it from the following link:

# URL of the Auto.csv dataset
url = "https://raw.githubusercontent.com/selva86/datasets/master/Auto.csv"

# Read the CSV file from the URL
df = pd.read_csv(url)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
# Out:
# array([130, 165, 150, 140, 198, 220, 215, 225, 190, 170, 160,  95,  97,
#         85,  88,  46,  87,  90, 113, 200, 210, 193, 100, 105, 175, 153,
#        180, 110,  72,  86,  70,  76,  65,  69,  60,  80,  54, 208, 155,
#        112,  92, 145, 137, 158, 167,  94, 107, 230,  49,  75,  91, 122,
#         67,  83,  78,  52,  61,  93, 148, 129,  96,  71,  98, 115,  53,
#         81,  79, 120, 152, 102, 108,  68,  58, 149,  89,  63,  48,  66,
#        139, 103, 125, 133, 138, 135, 142,  77,  62, 132,  84,  64,  74,
#        116,  82])

# %%
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 72   13.0          8         307.0         130    4098          14.0    72
# 212  13.0          8         302.0         130    3870          15.0    76
# 222  15.0          8         302.0         130    4295          14.9    77
# 283  17.0          8         305.0         130    3840          15.4    79
#
#      origin                              name
# 0         1         chevrolet chevelle malibu
# 72        1  chevrolet chevelle concours (sw)
# 212       1                         ford f108
# 222       1           mercury cougar brougham
# 283       1         chevrolet caprice classic

# %%
# Out:
# C:\Users\baage\AppData\Local\Temp\ipykernel_3728\1249145054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['horsepower'] = df['horsepower'].astype(int)

# %%
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
# Out:
# Does the DataFrame contain NaN values? False

# %%
# Out:
# Locations of NaN values:
#        mpg  cylinders  displacement  horsepower  weight  acceleration   year  \
# 0    False      False         False       False   False         False  False
# 72   False      False         False       False   False         False  False
# 212  False      False         False       False   False         False  False
# 222  False      False         False       False   False         False  False
# 283  False      False         False       False   False         False  False
#
#      origin   name
# 0     False  False
# 72    False  False
# 212   False  False
# 222   False  False
# 283   False  False

# %% [markdown]
# #### Exploratory data analysis (EDA) using Seaborn

# %%
import seaborn as sns

# %% [markdown]
# **Boxplot**

# %%
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %% [markdown]
# **Histogram**

# %% [markdown]
# **Pairplot**

# %% [markdown]
# **Correlation and heatmap**

# %%
# Out:
# <Axes: >

# %% [markdown]
# ### Linear regression with  statsmodel

# %%
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.648
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                     718.7
# Date:                Wed, 29 Jan 2025   Prob (F-statistic):           1.66e-90
# Time:                        17:53:22   Log-Likelihood:                -1156.4
# No. Observations:                 392   AIC:                             2317.
# Df Residuals:                     390   BIC:                             2325.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         35.1206      0.494     71.033      0.000      34.149      36.093
# ...

# %%
# Out:
# Text(0, 0.5, 'mpg')

# %% [markdown]
# ### multiple regression

# %%
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.990e+27
# Date:                Wed, 29 Jan 2025   Prob (F-statistic):               0.00
# Time:                        17:59:11   Log-Likelihood:                 10281.
# No. Observations:                 392   AIC:                        -2.054e+04
# Df Residuals:                     383   BIC:                        -2.051e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.382e-13   1.42e-12     -0.450      0.653   -3.43e-12    2.15e-12
# ...
